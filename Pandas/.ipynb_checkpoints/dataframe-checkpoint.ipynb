# %%
import pandas as pd

# %%
info = {
    "name":["Adam", "Eve","Bob","Ibrahim","Mahamud","Shafiq"],
    "age":[24,34,32,45,12]
}

# %%
df = pd.DataFrame(info)

# %%
df
# Out:
#       name  age
# 0     Adam   24
# 1      Eve   34
# 2      Bob   32
# 3  Ibrahim   45
# 4  Mahamud   12
# 5   Shafiq   23
